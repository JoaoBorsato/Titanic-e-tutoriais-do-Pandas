# %% [markdown]
# <img src="https://github.com/danielscarvalho/data/blob/master/img/FIAP-logo.png?raw=True" style="float:right;" width="200px">
#
# # DATA SCIENCE & STATISTICAL COMPUTING [》](https://www.fiap.com.br/)
#
# ## Dataframe & Python
#
# ### LAP Parte 1: “10 minutes to pandas"
#
# https://pandas.pydata.org/docs/user_guide/10min.html

# %% [markdown]
# Sugestão: Colocar a página do Cookbook lado a lado com este notebook para realizar as operações.

# %%
import numpy as np
import pandas as pd

# %%
pd.show_versions()
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 0f437949513225922d851e9581723d82120684a6
# python           : 3.10.12.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 6.1.58+
# Version          : #1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 2.0.3
# numpy            : 1.25.2
# pytz             : 2023.4
# dateutil         : 2.8.2
# setuptools       : 67.7.2
# pip              : 23.1.2
# Cython           : 3.0.10
# pytest           : 7.4.4
# hypothesis       : None
# sphinx           : 5.0.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.4
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : 2.9.9
# jinja2           : 3.1.3
# IPython          : 7.34.0
# pandas_datareader: 0.10.0
# bs4              : 4.12.3
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : 2023.6.0
# gcsfs            : 2023.6.0
# matplotlib       : 3.7.1
# numba            : 0.58.1
# numexpr          : 2.10.0
# odfpy            : None
# openpyxl         : 3.1.2
# pandas_gbq       : 0.19.2
# pyarrow          : 14.0.2
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.11.4
# snappy           : None
# sqlalchemy       : 2.0.29
# tables           : 3.8.0
# tabulate         : 0.9.0
# xarray           : 2023.7.0
# xlrd             : 2.0.1
# zstandard        : None
# tzdata           : 2024.1
# qtpy             : None
# pyqt5            : None

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.576803 -0.974918 -0.980426  0.610725
# 2013-01-02  1.744061  0.662852 -1.335354  0.547783
# 2013-01-03 -0.510326  0.209083  1.833262  0.228182
# 2013-01-04  0.422996  1.227483  1.139610 -0.124935
# 2013-01-05  0.686873 -0.436761 -1.190482 -0.516424
# 2013-01-06 -0.437465 -1.820017 -0.049139 -1.342645

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.980426  5.0  NaN
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0
# 2013-01-05  0.686873 -0.436761 -1.190482  5.0  4.0

# %%
df.tail(3)
# Out:
#                    A         B         C    D    F
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0
# 2013-01-05  0.686873 -0.436761 -1.190482  5.0  4.0
# 2013-01-06 -0.437465 -1.820017 -0.049139  5.0  5.0

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'F'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.        ,  0.        , -0.98042564,  5.        ,         nan],
#        [ 1.74406065,  0.66285154, -1.33535437,  5.        ,  1.        ],
#        [-0.51032633,  0.20908311,  1.83326236,  5.        ,  2.        ],
#        [ 0.422996  ,  1.22748346,  1.13960955,  5.        ,  3.        ],
#        [ 0.68687317, -0.436761  , -1.19048196,  5.        ,  4.        ],
#        [-0.43746488, -1.82001724, -0.04913915,  5.        ,  5.        ]])

# %%
df2.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# F    float64
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[ 0.        ,  0.        , -0.98042564, -5.        ,         nan],
#        [-1.74406065, -0.66285154, -1.33535437, -5.        , -1.        ],
#        [-0.51032633, -0.20908311, -1.83326236, -5.        , -2.        ],
#        [-0.422996  , -1.22748346, -1.13960955, -5.        , -3.        ],
#        [-0.68687317, -0.436761  , -1.19048196, -5.        , -4.        ],
#        [-0.43746488, -1.82001724, -0.04913915, -5.        , -5.        ]])

# %%
df.describe()
# Out:
#               A         B         C    D         F
# count  6.000000  6.000000  6.000000  6.0  5.000000
# mean   0.317690 -0.026227 -0.097088  5.0  3.000000
# std    0.841275  1.047750  1.324166  0.0  1.581139
# min   -0.510326 -1.820017 -1.335354  5.0  1.000000
# 25%   -0.328099 -0.327571 -1.137968  5.0  2.000000
# 50%    0.211498  0.104542 -0.514782  5.0  3.000000
# 75%    0.620904  0.549409  0.842422  5.0  4.000000
# max    1.744061  1.227483  1.833262  5.0  5.000000

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.000000    1.744061   -0.510326    0.422996    0.686873   -0.437465
# B    0.000000    0.662852    0.209083    1.227483   -0.436761   -1.820017
# C   -0.980426   -1.335354    1.833262    1.139610   -1.190482   -0.049139
# D    5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
# F         NaN    1.000000    2.000000    3.000000    4.000000    5.000000

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#               F    D         C         B         A
# 2013-01-01  NaN  5.0 -0.980426  0.000000  0.000000
# 2013-01-02  1.0  5.0 -1.335354  0.662852  1.744061
# 2013-01-03  2.0  5.0  1.833262  0.209083 -0.510326
# 2013-01-04  3.0  5.0  1.139610  1.227483  0.422996
# 2013-01-05  4.0  5.0 -1.190482 -0.436761  0.686873
# 2013-01-06  5.0  5.0 -0.049139 -1.820017 -0.437465

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C    D    F
# 2013-01-06 -0.437465 -1.820017 -0.049139  5.0  5.0
# 2013-01-05  0.686873 -0.436761 -1.190482  5.0  4.0
# 2013-01-01  0.000000  0.000000 -0.980426  5.0  NaN
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0

# %%
df["A"]
# Out:
# 2013-01-01    0.000000
# 2013-01-02    1.744061
# 2013-01-03   -0.510326
# 2013-01-04    0.422996
# 2013-01-05    0.686873
# 2013-01-06   -0.437465
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.980426  5.0  NaN
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0

# %%
df[1:-1]
# Out:
#                    A         B         C    D    F
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0
# 2013-01-05  0.686873 -0.436761 -1.190482  5.0  4.0

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.980426  5.0  NaN
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0
# 2013-01-05  0.686873 -0.436761 -1.190482  5.0  4.0
# 2013-01-06 -0.437465 -1.820017 -0.049139  5.0  5.0

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C    D    F
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0

# %%
df.loc[dates[0]]
# Out:
# A    0.576803
# B   -0.974918
# C   -0.980426
# D    0.610725
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.576803 -0.974918
# 2013-01-02  1.744061  0.662852
# 2013-01-03 -0.510326  0.209083
# 2013-01-04  0.422996  1.227483
# 2013-01-05  0.686873 -0.436761
# 2013-01-06 -0.437465 -1.820017

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  1.744061  0.662852
# 2013-01-03 -0.510326  0.209083
# 2013-01-04  0.422996  1.227483

# %%
df.loc[dates[0], "A"]
# Out:
# 0.5768030486841562

# %%
df.at[dates[0], "A"]
# Out:
# 0.5768030486841562

# %%
df.iloc[3]
# Out:
# A    0.422996
# B    1.227483
# C    1.139610
# D   -0.124935
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.422996  1.227483
# 2013-01-05  0.686873 -0.436761

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  1.744061 -1.335354
# 2013-01-03 -0.510326  1.833262
# 2013-01-05  0.686873 -1.190482

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.744061  0.662852 -1.335354  0.547783
# 2013-01-03 -0.510326  0.209083  1.833262  0.228182

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -0.974918 -0.980426
# 2013-01-02  0.662852 -1.335354
# 2013-01-03  0.209083  1.833262
# 2013-01-04  1.227483  1.139610
# 2013-01-05 -0.436761 -1.190482
# 2013-01-06 -1.820017 -0.049139

# %%
df.iloc[1, 1]
# Out:
# 0.6628515404913478

# %%
df.iat[1, 1]
# Out:
# 0.6628515404913478

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.576803 -0.974918 -0.980426  0.610725
# 2013-01-02  1.744061  0.662852 -1.335354  0.547783
# 2013-01-04  0.422996  1.227483  1.139610 -0.124935
# 2013-01-05  0.686873 -0.436761 -1.190482 -0.516424

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.576803       NaN       NaN  0.610725
# 2013-01-02  1.744061  0.662852       NaN  0.547783
# 2013-01-03       NaN  0.209083  1.833262  0.228182
# 2013-01-04  0.422996  1.227483  1.139610       NaN
# 2013-01-05  0.686873       NaN       NaN       NaN
# 2013-01-06       NaN       NaN       NaN       NaN

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.576803       NaN       NaN  0.610725
# 2013-01-02  1.744061  0.662852       NaN  0.547783
# 2013-01-03       NaN  0.209083  1.833262  0.228182
# 2013-01-04  0.422996  1.227483  1.139610       NaN
# 2013-01-05  0.686873       NaN       NaN       NaN
# 2013-01-06       NaN       NaN       NaN       NaN

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.576803 -0.974918 -0.980426  0.610725    one
# 2013-01-02  1.744061  0.662852 -1.335354  0.547783    one
# 2013-01-03 -0.510326  0.209083  1.833262  0.228182    two
# 2013-01-04  0.422996  1.227483  1.139610 -0.124935  three
# 2013-01-05  0.686873 -0.436761 -1.190482 -0.516424   four
# 2013-01-06 -0.437465 -1.820017 -0.049139 -1.342645  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.510326  0.209083  1.833262  0.228182   two
# 2013-01-05  0.686873 -0.436761 -1.190482 -0.516424  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.980426  5.0  NaN
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0
# 2013-01-05  0.686873 -0.436761 -1.190482  5.0  4.0
# 2013-01-06 -0.437465 -1.820017 -0.049139  5.0  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.980426 -5.0  NaN
# 2013-01-02 -1.744061 -0.662852 -1.335354 -5.0 -1.0
# 2013-01-03 -0.510326 -0.209083 -1.833262 -5.0 -2.0
# 2013-01-04 -0.422996 -1.227483 -1.139610 -5.0 -3.0
# 2013-01-05 -0.686873 -0.436761 -1.190482 -5.0 -4.0
# 2013-01-06 -0.437465 -1.820017 -0.049139 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.980426  5.0  NaN  1.0
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0  NaN
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.980426  5.0  5.0  1.0
# 2013-01-02  1.744061  0.662852 -1.335354  5.0  1.0  1.0
# 2013-01-03 -0.510326  0.209083  1.833262  5.0  2.0  5.0
# 2013-01-04  0.422996  1.227483  1.139610  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.317690
# B   -0.026227
# C   -0.097088
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.004894
# 2013-01-02    1.414312
# 2013-01-03    1.706404
# 2013-01-04    2.158018
# 2013-01-05    1.611926
# 2013-01-06    1.538676
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.510326 -0.790917  0.833262  4.0  1.0
# 2013-01-04 -2.577004 -1.772517 -1.860390  2.0  0.0
# 2013-01-05 -4.313127 -5.436761 -6.190482  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A     1.779063
# B    -0.146869
# C    -0.543694
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000  -99.219075  506.0    NaN
# 2013-01-02  176.498938   67.080576 -135.137863  506.0  101.2
# 2013-01-03  -51.645025   21.159211  185.526151  506.0  202.4
# 2013-01-04   42.807195  124.221326  115.328486  506.0  303.6
# 2013-01-05   69.511565  -44.200213 -120.476774  506.0  404.8
# 2013-01-06  -44.271446 -184.185745   -4.972882  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    5
# 1    2
# 2    3
# 3    0
# 4    5
# 5    5
# 6    2
# 7    6
# 8    5
# 9    6
# dtype: int64

# %%
s.value_counts()
# Out:
# 5    4
# 2    2
# 6    2
# 3    1
# 0    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.605871  2.413940 -0.364764 -1.711288
# 1  1.652692 -0.388404  0.664085 -0.161084
# 2  0.826635 -0.303664 -0.447938  1.225051
# 3  0.407861  0.108539  0.346306 -0.054772
# 4 -3.679209 -0.432086 -2.258346  0.216728
# 5  1.111004 -0.322047  0.910160  1.568685
# 6 -0.669936 -0.010529  1.312213  0.578756
# 7  0.805669  0.445800 -0.624213 -0.856060
# 8 -2.274650 -0.142409  0.975987  0.273914
# 9  0.466772 -0.147347  2.568233 -0.265827

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.605871  2.413940 -0.364764 -1.711288
# 1  1.652692 -0.388404  0.664085 -0.161084
# 2  0.826635 -0.303664 -0.447938  1.225051
# 3  0.407861  0.108539  0.346306 -0.054772
# 4 -3.679209 -0.432086 -2.258346  0.216728
# 5  1.111004 -0.322047  0.910160  1.568685
# 6 -0.669936 -0.010529  1.312213  0.578756
# 7  0.805669  0.445800 -0.624213 -0.856060
# 8 -2.274650 -0.142409  0.975987  0.273914
# 9  0.466772 -0.147347  2.568233 -0.265827

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.599618  2.026143
# 1  bar    one -0.412049 -0.974726
# 2  foo    two  1.386119 -0.451267
# 3  bar  three -2.813166 -0.857365
# 4  foo    two -0.282270 -0.367560
# 5  bar    two -0.490726  0.944863
# 6  foo    one -0.020673 -1.092902
# 7  foo  three -1.092225  1.250900

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -3.715941 -0.887229
# foo -0.608668  1.365314

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.412049 -0.974726
#     three -2.813166 -0.857365
#     two   -0.490726  0.944863
# foo one   -0.620291  0.933241
#     three -1.092225  1.250900
#     two    1.103848 -0.818827

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     1.871112 -1.278433
#       two    -2.381131  1.742485
# baz   one     1.693438  0.625287
#       two    -0.436443  0.458030

# %%
stacked = df2.stack(future_stack=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-99711964d23b> in <cell line: 1>()
# ----> 1 stacked = df2.stack(future_stack=True)
#
# TypeError: DataFrame.stack() got an unexpected keyword argument 'future_stack'

# %%
stacked
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-03c8261ccb16> in <cell line: 1>()
# ----> 1 stacked
#
# NameError: name 'stacked' is not defined

# %%
stacked.unstack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-9c37e54518c9> in <cell line: 1>()
# ----> 1 stacked.unstack()
#
# NameError: name 'stacked' is not defined

# %%
stacked.unstack(1)

# %%
stacked.unstack(0)

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.190821 -1.280487
# 1     one  B  foo  0.707918  0.263068
# 2     two  C  foo -2.176569 -0.144314
# 3   three  A  bar  1.304151  0.119613
# 4     one  B  bar  1.272272  0.776728
# 5     one  C  bar -2.146014  0.894175
# 6     two  A  foo  0.031122  0.522573
# 7   three  B  foo -0.342812  1.539550
# 8     one  C  foo  1.816714  0.598544
# 9     one  A  bar -0.444591  0.241501
# 10    two  B  bar -0.615436  0.746129
# 11  three  C  bar  0.981417  0.607919

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.444591  0.190821
#       B  1.272272  0.707918
#       C -2.146014  1.816714
# three A  1.304151       NaN
#       B       NaN -0.342812
#       C  0.981417       NaN
# two   A       NaN  0.031122
#       B -0.615436       NaN
#       C       NaN -2.176569

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-126-75add6f71a5d> in <cell line: 1>()
# ----> 1 ts.resample("5Min").sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    5717             if len(entry) != 2:
#    5718                 raise ValueError(
# -> 5719                     f"Argument {num} must have length 2; "
#    5720                     "a condition and replacement; "
#    5721                     f"instead got length {len(entry)}."
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    8883         self,
#    8884         lower=...,
# -> 8885         upper=...,
#    8886         *,
#    8887         axis: Axis | None = ...,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in <module>
#      25     to_offset,
#      26 )
# ---> 27 from pandas._libs.tslibs.dtypes import freq_to_period_freqstr
#      28 from pandas._typing import NDFrameT
#      29 from pandas.compat.numpy import function as nv
#
# ImportError: cannot import name 'freq_to_period_freqstr' from 'pandas._libs.tslibs.dtypes' (/usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/dtypes.cpython-310-x86_64-linux-gnu.so)

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.707782
# 2012-03-07   -0.649001
# 2012-03-08    0.185956
# 2012-03-09   -1.362314
# 2012-03-10   -1.481175
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.707782
# 2012-03-07 00:00:00+00:00   -0.649001
# 2012-03-08 00:00:00+00:00    0.185956
# 2012-03-09 00:00:00+00:00   -1.362314
# 2012-03-10 00:00:00+00:00   -1.481175
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -0.707782
# 2012-03-06 19:00:00-05:00   -0.649001
# 2012-03-07 19:00:00-05:00    0.185956
# 2012-03-08 19:00:00-05:00   -1.362314
# 2012-03-09 19:00:00-05:00   -1.481175
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df = df.cumsum()

# %%
plt.figure();

# %%
df.plot();

# %%
plt.legend(loc='best');
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

# %%
df.to_csv("foo.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-168-ddb7ec1ef57f> in <cell line: 1>()
# ----> 1 df.to_csv("foo.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         path_or_buf: FilePath | WriteBuffer[bytes] | WriteBuffer[str],
#    3771         sep: str = ...,
# -> 3772         na_rep: str = ...,
#    3773         float_format: str | Callable | None = ...,
#    3774         columns: Sequence[Hashable] | None = ...,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1157         quoting=quoting,
#    1158         fallback_formatter=fallback_formatter,
# -> 1159     )
#    1160
#    1161     return fmt_obj.get_result()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in <module>
#      22
#      23 from pandas._libs import writers as libwriters
# ---> 24 from pandas._typing import SequenceNotStr
#      25 from pandas.util._decorators import cache_readonly
#      26
#
# ImportError: cannot import name 'SequenceNotStr' from 'pandas._typing' (/usr/local/lib/python3.10/dist-packages/pandas/_typing.py)

# %%
df.to_csv("foo.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-169-ddb7ec1ef57f> in <cell line: 1>()
# ----> 1 df.to_csv("foo.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         path_or_buf: FilePath | WriteBuffer[bytes] | WriteBuffer[str],
#    3771         sep: str = ...,
# -> 3772         na_rep: str = ...,
#    3773         float_format: str | Callable | None = ...,
#    3774         columns: Sequence[Hashable] | None = ...,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1157         quoting=quoting,
#    1158         fallback_formatter=fallback_formatter,
# -> 1159     )
#    1160
#    1161     return fmt_obj.get_result()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in <module>
#      22
#      23 from pandas._libs import writers as libwriters
# ---> 24 from pandas._typing import SequenceNotStr
#      25 from pandas.util._decorators import cache_readonly
#      26
#
# ImportError: cannot import name 'SequenceNotStr' from 'pandas._typing' (/usr/local/lib/python3.10/dist-packages/pandas/_typing.py)

# %%
pd.read_csv("foo.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-170-5db89991207f> in <cell line: 1>()
# ----> 1 pd.read_csv("foo.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     parse_dates: bool | Sequence[Hashable] | None = None,
#     911     infer_datetime_format: bool | lib.NoDefault = lib.no_default,
# --> 912     keep_date_col: bool | lib.NoDefault = lib.no_default,
#     913     date_parser: Callable | lib.NoDefault = lib.no_default,
#     914     date_format: str | dict[Hashable, str] | None = None,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575         if len(names) != len(set(names)):
#     576             raise ValueError("Duplicate names are not allowed.")
# --> 577         if not (
#     578             is_list_like(names, allow_sets=False) or isinstance(names, abc.KeysView)
#     579         ):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405     return _read(filepath_or_buffer, kwds)
#    1406
# -> 1407
#    1408 @overload
#    1409 def read_fwf(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                     else:
#    1660                         raise ValueError(
# -> 1661                             f"The {repr(argname)} option is not supported with the "
#    1662                             f"{repr(engine)} engine"
#    1663                         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857                 **open_args,
#     858             )
# --> 859
#     860         # Unrecognized Compression
#     861         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'foo.csv'

# %%
df.to_parquet("foo.parquet")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-171-13f7da838c3c> in <cell line: 1>()
# ----> 1 df.to_parquet("foo.parquet")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2887             data_label=data_label,
#    2888             write_index=write_index,
# -> 2889             variable_labels=variable_labels,
#    2890             compression=compression,
#    2891             storage_options=storage_options,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     405             if handles is not None:
#     406                 handles.close()
# --> 407
#     408
#     409 @doc(storage_options=_shared_docs["storage_options"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in get_engine(engine)
#      58         engine_classes = [PyArrowImpl, FastParquetImpl]
#      59
# ---> 60         error_msgs = ""
#      61         for engine_class in engine_classes:
#      62             try:
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - cannot import name 'pa_version_under14p1' from 'pandas.compat' (/usr/local/lib/python3.10/dist-packages/pandas/compat/__init__.py)
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
pd.read_parquet("foo.parquet")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-172-6985cd20dcfe> in <cell line: 1>()
# ----> 1 pd.read_parquet("foo.parquet")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     491     if path is None:
#     492         assert isinstance(path_or_buf, io.BytesIO)
# --> 493         return path_or_buf.getvalue()
#     494     else:
#     495         return None
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in get_engine(engine)
#      58         engine_classes = [PyArrowImpl, FastParquetImpl]
#      59
# ---> 60         error_msgs = ""
#      61         for engine_class in engine_classes:
#      62             try:
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - cannot import name 'pa_version_under14p1' from 'pandas.compat' (/usr/local/lib/python3.10/dist-packages/pandas/compat/__init__.py)
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  3  0  0  3
# 1           1  2  3  3  1  4
# 2           2  3  2  3  0  1
# 3           3  4  1  0  0  3
# 4           4  1  0  3  2  1
# 5           5  3  3  2  0  2
# 6           6  4  0  1  0  0
# 7           7  1  4  4  3  0
# 8           8  0  0  4  2  4
# 9           9  3  1  3  3  4

# %%
if pd.Series([False, True, False]):
     print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-b27eb9c1dfc0> in <cell line: 1>()
# ----> 1 if pd.Series([False, True, False]):
#       2      print("I was true")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1464         bool
#    1465             True if all elements are the same in both objects, False
# -> 1466             otherwise.
#    1467
#    1468         See Also
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
